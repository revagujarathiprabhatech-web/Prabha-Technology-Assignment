# %% [markdown]
# 01/07/2026
#
# Assignment : 15
#
# Pandas Mini Project

# %%
# Create CSV Dataset

import pandas as pd

data = {
    "Student_ID": [101, 102, 103, 104, 105, 106, 107, 108, 109, 110, 111, 112, 113],
    "Name": ["Raj", "Amit", "Priya", "Sneha", "Rahul", "Pooja", "Karan", "Neha", "Akash", "Komal", "Vikas", "Riya", "Raj"],
    "Age": [21, 22, 20, 23, 21, 22, 20, 21, 24, 23, None, 22, 21],
    "Gender": ["Male", "Male", "Female", "Female", "Male", "Female", "Male", "Female", "Male", "Female", "Male", "Female", "Male"],
    "City": ["Pune", "Mumbai", "Nashik", "Pune", "Mumbai", "Pune", "Nashik", "Pune", "Mumbai", "Pune", "Pune", "Mumbai", "Pune"],
    "Course": ["Python", "AI", "Python", "Data Science", "AI", "Python", "Data Science", "AI", "Python", "Data Science", "Python", "AI", "Python"],
    "Attendance": [90, 80, 95, 88, 75, 98, 82, 91, 85, 96, 90, None, 90],
    "Marks": [85, 75, 92, 81, 65, 96, 79, 89, 72, 94, None, 85, 85],
    "Purchased": ["Yes", "No", "Yes", "Yes", "No", "Yes", "No", "Yes", "No", "Yes", "Yes", "No", "Yes"]
}

df = pd.DataFrame(data)

# Save as CSV
df.to_csv("student_performance.csv", index=False)

print("student_performance.csv created successfully!")
# Out:
# student_performance.csv created successfully!

# %%
# Load Dataset

df = pd.read_csv("student_performance.csv")

df
# Out:
#     Student_ID   Name   Age  Gender    City        Course  Attendance  Marks  \
# 0          101    Raj  21.0    Male    Pune        Python        90.0   85.0
# 1          102   Amit  22.0    Male  Mumbai            AI        80.0   75.0
# 2          103  Priya  20.0  Female  Nashik        Python        95.0   92.0
# 3          104  Sneha  23.0  Female    Pune  Data Science        88.0   81.0
# 4          105  Rahul  21.0    Male  Mumbai            AI        75.0   65.0
# 5          106  Pooja  22.0  Female    Pune        Python        98.0   96.0
# 6          107  Karan  20.0    Male  Nashik  Data Science        82.0   79.0
# 7          108   Neha  21.0  Female    Pune            AI        91.0   89.0
# 8          109  Akash  24.0    Male  Mumbai        Python        85.0   72.0
# 9          110  Komal  23.0  Female    Pune  Data Science        96.0   94.0
# 10         111  Vikas   NaN    Male    Pune        Python        90.0    NaN
# ...

# %%
# First 5 rows
df.head()
# Out:
#    Student_ID   Name   Age  Gender    City        Course  Attendance  Marks  \
# 0         101    Raj  21.0    Male    Pune        Python        90.0   85.0
# 1         102   Amit  22.0    Male  Mumbai            AI        80.0   75.0
# 2         103  Priya  20.0  Female  Nashik        Python        95.0   92.0
# 3         104  Sneha  23.0  Female    Pune  Data Science        88.0   81.0
# 4         105  Rahul  21.0    Male  Mumbai            AI        75.0   65.0
#
#   Purchased
# 0       Yes
# 1        No
# 2       Yes
# 3       Yes
# 4        No

# %%
# Last 5 rows
df.tail()
# Out:
#     Student_ID   Name   Age  Gender    City        Course  Attendance  Marks  \
# 8          109  Akash  24.0    Male  Mumbai        Python        85.0   72.0
# 9          110  Komal  23.0  Female    Pune  Data Science        96.0   94.0
# 10         111  Vikas   NaN    Male    Pune        Python        90.0    NaN
# 11         112   Riya  22.0  Female  Mumbai            AI         NaN   85.0
# 12         113    Raj  21.0    Male    Pune        Python        90.0   85.0
#
#    Purchased
# 8         No
# 9        Yes
# 10       Yes
# 11        No
# 12       Yes

# %%
# Shape
print("Shape:", df.shape)
# Out:
# Shape: (13, 9)

# %%
# Column names
print(df.columns)
# Out:
# Index(['Student_ID', 'Name', 'Age', 'Gender', 'City', 'Course', 'Attendance',
#        'Marks', 'Purchased'],
#       dtype='object')

# %%
# Data types
print(df.dtypes)
# Out:
# Student_ID      int64
# Name           object
# Age           float64
# Gender         object
# City           object
# Course         object
# Attendance    float64
# Marks         float64
# Purchased      object
# dtype: object

# %%
# Dataset information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Student_ID  13 non-null     int64
#  1   Name        13 non-null     object
#  2   Age         12 non-null     float64
#  3   Gender      13 non-null     object
#  4   City        13 non-null     object
#  5   Course      13 non-null     object
#  6   Attendance  12 non-null     float64
#  7   Marks       12 non-null     float64
#  8   Purchased   13 non-null     object
# dtypes: float64(3), int64(1), object(5)
# memory usage: 1.0+ KB

# %%
# Statistical summary
df.describe()
# Out:
#        Student_ID        Age  Attendance      Marks
# count    13.00000  12.000000   12.000000  12.000000
# mean    107.00000  21.666667   88.333333  83.166667
# std       3.89444   1.230915    6.813534   9.281784
# min     101.00000  20.000000   75.000000  65.000000
# 25%     104.00000  21.000000   84.250000  78.000000
# 50%     107.00000  21.500000   90.000000  85.000000
# 75%     110.00000  22.250000   92.000000  89.750000
# max     113.00000  24.000000   98.000000  96.000000

# %%
# Find missing values
df.isnull()
# Out:
#     Student_ID   Name    Age  Gender   City  Course  Attendance  Marks  \
# 0        False  False  False   False  False   False       False  False
# 1        False  False  False   False  False   False       False  False
# 2        False  False  False   False  False   False       False  False
# 3        False  False  False   False  False   False       False  False
# 4        False  False  False   False  False   False       False  False
# 5        False  False  False   False  False   False       False  False
# 6        False  False  False   False  False   False       False  False
# 7        False  False  False   False  False   False       False  False
# 8        False  False  False   False  False   False       False  False
# 9        False  False  False   False  False   False       False  False
# 10       False  False   True   False  False   False       False   True
# 11       False  False  False   False  False   False        True  False
# ...

# %%
# Count missing values
df.isnull().sum()
# Out:
# Student_ID    0
# Name          0
# Age           1
# Gender        0
# City          0
# Course        0
# Attendance    1
# Marks         1
# Purchased     0
# dtype: int64

# %%
# Fill missing Age with average
df["Age"] = df["Age"].fillna(df["Age"].mean())

# Fill missing Marks with average
df["Marks"] = df["Marks"].fillna(df["Marks"].mean())

# Fill missing Attendance with average
df["Attendance"] = df["Attendance"].fillna(df["Attendance"].mean())

# %%
# Verify missing values
df.isnull().sum()
# Out:
# Student_ID    0
# Name          0
# Age           0
# Gender        0
# City          0
# Course        0
# Attendance    0
# Marks         0
# Purchased     0
# dtype: int64

# %%
# Count duplicate rows
print("Duplicate rows:", df.duplicated().sum())
# Out:
# Duplicate rows: 0

# %%
# Remove duplicates
df = df.drop_duplicates()

# %%
# Display cleaned dataset
df
# Out:
#     Student_ID   Name        Age  Gender    City        Course  Attendance  \
# 0          101    Raj  21.000000    Male    Pune        Python   90.000000
# 1          102   Amit  22.000000    Male  Mumbai            AI   80.000000
# 2          103  Priya  20.000000  Female  Nashik        Python   95.000000
# 3          104  Sneha  23.000000  Female    Pune  Data Science   88.000000
# 4          105  Rahul  21.000000    Male  Mumbai            AI   75.000000
# 5          106  Pooja  22.000000  Female    Pune        Python   98.000000
# 6          107  Karan  20.000000    Male  Nashik  Data Science   82.000000
# 7          108   Neha  21.000000  Female    Pune            AI   91.000000
# 8          109  Akash  24.000000    Male  Mumbai        Python   85.000000
# 9          110  Komal  23.000000  Female    Pune  Data Science   96.000000
# 10         111  Vikas  21.666667    Male    Pune        Python   90.000000
# ...

# %%
# Name column
df["Name"]
# Out:
# 0       Raj
# 1      Amit
# 2     Priya
# 3     Sneha
# 4     Rahul
# 5     Pooja
# 6     Karan
# 7      Neha
# 8     Akash
# 9     Komal
# 10    Vikas
# 11     Riya
# 12      Raj
# Name: Name, dtype: object

# %%
# Marks column
df["Marks"]
# Out:
# 0     85.000000
# 1     75.000000
# 2     92.000000
# 3     81.000000
# 4     65.000000
# 5     96.000000
# 6     79.000000
# 7     89.000000
# 8     72.000000
# 9     94.000000
# 10    83.166667
# 11    85.000000
# 12    85.000000
# Name: Marks, dtype: float64

# %%
# Name and Marks
df[["Name", "Marks"]]
# Out:
#      Name      Marks
# 0     Raj  85.000000
# 1    Amit  75.000000
# 2   Priya  92.000000
# 3   Sneha  81.000000
# 4   Rahul  65.000000
# 5   Pooja  96.000000
# 6   Karan  79.000000
# 7    Neha  89.000000
# 8   Akash  72.000000
# 9   Komal  94.000000
# 10  Vikas  83.166667
# 11   Riya  85.000000
# 12    Raj  85.000000

# %%
# Name, City and Course
df[["Name", "City", "Course"]]
# Out:
#      Name    City        Course
# 0     Raj    Pune        Python
# 1    Amit  Mumbai            AI
# 2   Priya  Nashik        Python
# 3   Sneha    Pune  Data Science
# 4   Rahul  Mumbai            AI
# 5   Pooja    Pune        Python
# 6   Karan  Nashik  Data Science
# 7    Neha    Pune            AI
# 8   Akash  Mumbai        Python
# 9   Komal    Pune  Data Science
# 10  Vikas    Pune        Python
# 11   Riya  Mumbai            AI
# 12    Raj    Pune        Python

# %%
# Marks greater than 80
df[df["Marks"] > 80]
# Out:
#     Student_ID   Name        Age  Gender    City        Course  Attendance  \
# 0          101    Raj  21.000000    Male    Pune        Python   90.000000
# 2          103  Priya  20.000000  Female  Nashik        Python   95.000000
# 3          104  Sneha  23.000000  Female    Pune  Data Science   88.000000
# 5          106  Pooja  22.000000  Female    Pune        Python   98.000000
# 7          108   Neha  21.000000  Female    Pune            AI   91.000000
# 9          110  Komal  23.000000  Female    Pune  Data Science   96.000000
# 10         111  Vikas  21.666667    Male    Pune        Python   90.000000
# 11         112   Riya  22.000000  Female  Mumbai            AI   88.333333
# 12         113    Raj  21.000000    Male    Pune        Python   90.000000
#
#         Marks Purchased
# 0   85.000000       Yes
# 2   92.000000       Yes
# 3   81.000000       Yes
# 5   96.000000       Yes
# 7   89.000000       Yes
# 9   94.000000       Yes
# 10  83.166667       Yes
# ...

# %%
# Marks less than 70
df[df["Marks"] < 70]
# Out:
#    Student_ID   Name   Age Gender    City Course  Attendance  Marks Purchased
# 4         105  Rahul  21.0   Male  Mumbai     AI        75.0   65.0        No

# %%
# Students from Pune
df[df["City"] == "Pune"]
# Out:
#     Student_ID   Name        Age  Gender  City        Course  Attendance  \
# 0          101    Raj  21.000000    Male  Pune        Python        90.0
# 3          104  Sneha  23.000000  Female  Pune  Data Science        88.0
# 5          106  Pooja  22.000000  Female  Pune        Python        98.0
# 7          108   Neha  21.000000  Female  Pune            AI        91.0
# 9          110  Komal  23.000000  Female  Pune  Data Science        96.0
# 10         111  Vikas  21.666667    Male  Pune        Python        90.0
# 12         113    Raj  21.000000    Male  Pune        Python        90.0
#
#         Marks Purchased
# 0   85.000000       Yes
# 3   81.000000       Yes
# 5   96.000000       Yes
# 7   89.000000       Yes
# 9   94.000000       Yes
# 10  83.166667       Yes
# 12  85.000000       Yes

# %%
# Students from Mumbai
df[df["City"] == "Mumbai"]
# Out:
#     Student_ID   Name   Age  Gender    City  Course  Attendance  Marks  \
# 1          102   Amit  22.0    Male  Mumbai      AI   80.000000   75.0
# 4          105  Rahul  21.0    Male  Mumbai      AI   75.000000   65.0
# 8          109  Akash  24.0    Male  Mumbai  Python   85.000000   72.0
# 11         112   Riya  22.0  Female  Mumbai      AI   88.333333   85.0
#
#    Purchased
# 1         No
# 4         No
# 8         No
# 11        No

# %%
# Female students
df[df["Gender"] == "Female"]
# Out:
#     Student_ID   Name   Age  Gender    City        Course  Attendance  Marks  \
# 2          103  Priya  20.0  Female  Nashik        Python   95.000000   92.0
# 3          104  Sneha  23.0  Female    Pune  Data Science   88.000000   81.0
# 5          106  Pooja  22.0  Female    Pune        Python   98.000000   96.0
# 7          108   Neha  21.0  Female    Pune            AI   91.000000   89.0
# 9          110  Komal  23.0  Female    Pune  Data Science   96.000000   94.0
# 11         112   Riya  22.0  Female  Mumbai            AI   88.333333   85.0
#
#    Purchased
# 2        Yes
# 3        Yes
# 5        Yes
# 7        Yes
# 9        Yes
# 11        No

# %%
# Male students
df[df["Gender"] == "Male"]
# Out:
#     Student_ID   Name        Age Gender    City        Course  Attendance  \
# 0          101    Raj  21.000000   Male    Pune        Python        90.0
# 1          102   Amit  22.000000   Male  Mumbai            AI        80.0
# 4          105  Rahul  21.000000   Male  Mumbai            AI        75.0
# 6          107  Karan  20.000000   Male  Nashik  Data Science        82.0
# 8          109  Akash  24.000000   Male  Mumbai        Python        85.0
# 10         111  Vikas  21.666667   Male    Pune        Python        90.0
# 12         113    Raj  21.000000   Male    Pune        Python        90.0
#
#         Marks Purchased
# 0   85.000000       Yes
# 1   75.000000        No
# 4   65.000000        No
# 6   79.000000        No
# 8   72.000000        No
# 10  83.166667       Yes
# 12  85.000000       Yes

# %%
# AI students
df[df["Course"] == "AI"]
# Out:
#     Student_ID   Name   Age  Gender    City Course  Attendance  Marks  \
# 1          102   Amit  22.0    Male  Mumbai     AI   80.000000   75.0
# 4          105  Rahul  21.0    Male  Mumbai     AI   75.000000   65.0
# 7          108   Neha  21.0  Female    Pune     AI   91.000000   89.0
# 11         112   Riya  22.0  Female  Mumbai     AI   88.333333   85.0
#
#    Purchased
# 1         No
# 4         No
# 7        Yes
# 11        No

# %%
# Python students
df[df["Course"] == "Python"]
# Out:
#     Student_ID   Name        Age  Gender    City  Course  Attendance  \
# 0          101    Raj  21.000000    Male    Pune  Python        90.0
# 2          103  Priya  20.000000  Female  Nashik  Python        95.0
# 5          106  Pooja  22.000000  Female    Pune  Python        98.0
# 8          109  Akash  24.000000    Male  Mumbai  Python        85.0
# 10         111  Vikas  21.666667    Male    Pune  Python        90.0
# 12         113    Raj  21.000000    Male    Pune  Python        90.0
#
#         Marks Purchased
# 0   85.000000       Yes
# 2   92.000000       Yes
# 5   96.000000       Yes
# 8   72.000000        No
# 10  83.166667       Yes
# 12  85.000000       Yes

# %%
# Attendance greater than 90
df[df["Attendance"] > 90]
# Out:
#    Student_ID   Name   Age  Gender    City        Course  Attendance  Marks  \
# 2         103  Priya  20.0  Female  Nashik        Python        95.0   92.0
# 5         106  Pooja  22.0  Female    Pune        Python        98.0   96.0
# 7         108   Neha  21.0  Female    Pune            AI        91.0   89.0
# 9         110  Komal  23.0  Female    Pune  Data Science        96.0   94.0
#
#   Purchased
# 2       Yes
# 5       Yes
# 7       Yes
# 9       Yes

# %%
# Marks between 70 and 90
df[df["Marks"].between(70, 90)]
# Out:
#     Student_ID   Name        Age  Gender    City        Course  Attendance  \
# 0          101    Raj  21.000000    Male    Pune        Python   90.000000
# 1          102   Amit  22.000000    Male  Mumbai            AI   80.000000
# 3          104  Sneha  23.000000  Female    Pune  Data Science   88.000000
# 6          107  Karan  20.000000    Male  Nashik  Data Science   82.000000
# 7          108   Neha  21.000000  Female    Pune            AI   91.000000
# 8          109  Akash  24.000000    Male  Mumbai        Python   85.000000
# 10         111  Vikas  21.666667    Male    Pune        Python   90.000000
# 11         112   Riya  22.000000  Female  Mumbai            AI   88.333333
# 12         113    Raj  21.000000    Male    Pune        Python   90.000000
#
#         Marks Purchased
# 0   85.000000       Yes
# 1   75.000000        No
# 3   81.000000       Yes
# 6   79.000000        No
# 7   89.000000       Yes
# 8   72.000000        No
# 10  83.166667       Yes
# ...

# %%
# Male students from Pune
df[(df["Gender"] == "Male") & (df["City"] == "Pune")]
# Out:
#     Student_ID   Name        Age Gender  City  Course  Attendance      Marks  \
# 0          101    Raj  21.000000   Male  Pune  Python        90.0  85.000000
# 10         111  Vikas  21.666667   Male  Pune  Python        90.0  83.166667
# 12         113    Raj  21.000000   Male  Pune  Python        90.0  85.000000
#
#    Purchased
# 0        Yes
# 10       Yes
# 12       Yes

# %%
# Female students with Marks greater than 85
df[(df["Gender"] == "Female") & (df["Marks"] > 85)]
# Out:
#    Student_ID   Name   Age  Gender    City        Course  Attendance  Marks  \
# 2         103  Priya  20.0  Female  Nashik        Python        95.0   92.0
# 5         106  Pooja  22.0  Female    Pune        Python        98.0   96.0
# 7         108   Neha  21.0  Female    Pune            AI        91.0   89.0
# 9         110  Komal  23.0  Female    Pune  Data Science        96.0   94.0
#
#   Purchased
# 2       Yes
# 5       Yes
# 7       Yes
# 9       Yes

# %%
# Marks ascending
df.sort_values("Marks")
# Out:
#     Student_ID   Name        Age  Gender    City        Course  Attendance  \
# 4          105  Rahul  21.000000    Male  Mumbai            AI   75.000000
# 8          109  Akash  24.000000    Male  Mumbai        Python   85.000000
# 1          102   Amit  22.000000    Male  Mumbai            AI   80.000000
# 6          107  Karan  20.000000    Male  Nashik  Data Science   82.000000
# 3          104  Sneha  23.000000  Female    Pune  Data Science   88.000000
# 10         111  Vikas  21.666667    Male    Pune        Python   90.000000
# 0          101    Raj  21.000000    Male    Pune        Python   90.000000
# 11         112   Riya  22.000000  Female  Mumbai            AI   88.333333
# 12         113    Raj  21.000000    Male    Pune        Python   90.000000
# 7          108   Neha  21.000000  Female    Pune            AI   91.000000
# 2          103  Priya  20.000000  Female  Nashik        Python   95.000000
# ...

# %%
# Marks descending
df.sort_values("Marks", ascending=False)
# Out:
#     Student_ID   Name        Age  Gender    City        Course  Attendance  \
# 5          106  Pooja  22.000000  Female    Pune        Python   98.000000
# 9          110  Komal  23.000000  Female    Pune  Data Science   96.000000
# 2          103  Priya  20.000000  Female  Nashik        Python   95.000000
# 7          108   Neha  21.000000  Female    Pune            AI   91.000000
# 0          101    Raj  21.000000    Male    Pune        Python   90.000000
# 11         112   Riya  22.000000  Female  Mumbai            AI   88.333333
# 12         113    Raj  21.000000    Male    Pune        Python   90.000000
# 10         111  Vikas  21.666667    Male    Pune        Python   90.000000
# 3          104  Sneha  23.000000  Female    Pune  Data Science   88.000000
# 6          107  Karan  20.000000    Male  Nashik  Data Science   82.000000
# 1          102   Amit  22.000000    Male  Mumbai            AI   80.000000
# ...

# %%
# Attendance highest to lowest
df.sort_values("Attendance", ascending=False)
# Out:
#     Student_ID   Name        Age  Gender    City        Course  Attendance  \
# 5          106  Pooja  22.000000  Female    Pune        Python   98.000000
# 9          110  Komal  23.000000  Female    Pune  Data Science   96.000000
# 2          103  Priya  20.000000  Female  Nashik        Python   95.000000
# 7          108   Neha  21.000000  Female    Pune            AI   91.000000
# 0          101    Raj  21.000000    Male    Pune        Python   90.000000
# 10         111  Vikas  21.666667    Male    Pune        Python   90.000000
# 12         113    Raj  21.000000    Male    Pune        Python   90.000000
# 11         112   Riya  22.000000  Female  Mumbai            AI   88.333333
# 3          104  Sneha  23.000000  Female    Pune  Data Science   88.000000
# 8          109  Akash  24.000000    Male  Mumbai        Python   85.000000
# 6          107  Karan  20.000000    Male  Nashik  Data Science   82.000000
# ...

# %%
# Age lowest to highest
df.sort_values("Age")
# Out:
#     Student_ID   Name        Age  Gender    City        Course  Attendance  \
# 2          103  Priya  20.000000  Female  Nashik        Python   95.000000
# 6          107  Karan  20.000000    Male  Nashik  Data Science   82.000000
# 0          101    Raj  21.000000    Male    Pune        Python   90.000000
# 4          105  Rahul  21.000000    Male  Mumbai            AI   75.000000
# 7          108   Neha  21.000000  Female    Pune            AI   91.000000
# 12         113    Raj  21.000000    Male    Pune        Python   90.000000
# 10         111  Vikas  21.666667    Male    Pune        Python   90.000000
# 1          102   Amit  22.000000    Male  Mumbai            AI   80.000000
# 5          106  Pooja  22.000000  Female    Pune        Python   98.000000
# 11         112   Riya  22.000000  Female  Mumbai            AI   88.333333
# 3          104  Sneha  23.000000  Female    Pune  Data Science   88.000000
# ...

# %%
# Unique Cities
df["City"].unique()
# Out:
# array(['Pune', 'Mumbai', 'Nashik'], dtype=object)

# %%
# Unique Courses
df["Course"].unique()
# Out:
# array(['Python', 'AI', 'Data Science'], dtype=object)

# %%
# Unique Gender values
df["Gender"].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
# Unique Purchased values
df["Purchased"].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
# Students in each City
df["City"].value_counts()
# Out:
# City
# Pune      7
# Mumbai    4
# Nashik    2
# Name: count, dtype: int64

# %%
# Students in each Course
df["Course"].value_counts()
# Out:
# Course
# Python          6
# AI              4
# Data Science    3
# Name: count, dtype: int64

# %%
# Male and Female students
df["Gender"].value_counts()
# Out:
# Gender
# Male      7
# Female    6
# Name: count, dtype: int64

# %%
# Purchased Yes and No
df["Purchased"].value_counts()
# Out:
# Purchased
# Yes    8
# No     5
# Name: count, dtype: int64

# %%
# Average Marks by Course
df.groupby("Course")["Marks"].mean()
# Out:
# Course
# AI              78.500000
# Data Science    84.666667
# Python          85.527778
# Name: Marks, dtype: float64

# %%
# Average Attendance by Course
df.groupby("Course")["Attendance"].mean()
# Out:
# Course
# AI              83.583333
# Data Science    88.666667
# Python          91.333333
# Name: Attendance, dtype: float64

# %%
# Total Marks by Course
df.groupby("Course")["Marks"].sum()
# Out:
# Course
# AI              314.000000
# Data Science    254.000000
# Python          513.166667
# Name: Marks, dtype: float64

# %%
# Maximum Marks by Course
df.groupby("Course")["Marks"].max()
# Out:
# Course
# AI              89.0
# Data Science    94.0
# Python          96.0
# Name: Marks, dtype: float64

# %%
# Minimum Marks by Course
df.groupby("Course")["Marks"].min()
# Out:
# Course
# AI              65.0
# Data Science    79.0
# Python          72.0
# Name: Marks, dtype: float64

# %%
# Total Students by Course
df.groupby("Course")["Student_ID"].count()
# Out:
# Course
# AI              4
# Data Science    3
# Python          6
# Name: Student_ID, dtype: int64

# %%
# Average Marks by Gender
df.groupby("Gender")["Marks"].mean()
# Out:
# Gender
# Female    89.500000
# Male      77.738095
# Name: Marks, dtype: float64

# %%
# Average Attendance by City
df.groupby("City")["Attendance"].mean()
# Out:
# City
# Mumbai    82.083333
# Nashik    88.500000
# Pune      91.857143
# Name: Attendance, dtype: float64

# %%
course_analysis = df.groupby("Course").agg({
    "Marks": ["sum", "mean", "min", "max"],
    "Student_ID": "count"
})

course_analysis
# Out:
#                    Marks                        Student_ID
#                      sum       mean   min   max      count
# Course
# AI            314.000000  78.500000  65.0  89.0          4
# Data Science  254.000000  84.666667  79.0  94.0          3
# Python        513.166667  85.527778  72.0  96.0          6

# %%
# Correlation between numerical columns
df.corr(numeric_only=True)
# Out:
#             Student_ID       Age  Attendance     Marks
# Student_ID    1.000000  0.211830    0.192436  0.146079
# Age           0.211830  1.000000    0.073467 -0.114050
# Attendance    0.192436  0.073467    1.000000  0.952015
# Marks         0.146079 -0.114050    0.952015  1.000000

# %%
# Highest positive correlation
correlation = df.corr(numeric_only=True)

print("Highest Positive Correlation:")
print(correlation.stack().sort_values(ascending=False).iloc[1])
# Out:
# Highest Positive Correlation:
# 1.0

# %%
# Lowest correlation
print("Lowest Correlation:")
print(correlation.stack().sort_values().iloc[0])
# Out:
# Lowest Correlation:
# -0.11404993013364456

# %%
# Gender Encoding
df["Gender"] = df["Gender"].map({
    "Male": 1,
    "Female": 0
})

# Purchased Encoding
df["Purchased"] = df["Purchased"].map({
    "Yes": 1,
    "No": 0
})

df
# Out:
#     Student_ID   Name        Age  Gender    City        Course  Attendance  \
# 0          101    Raj  21.000000       1    Pune        Python   90.000000
# 1          102   Amit  22.000000       1  Mumbai            AI   80.000000
# 2          103  Priya  20.000000       0  Nashik        Python   95.000000
# 3          104  Sneha  23.000000       0    Pune  Data Science   88.000000
# 4          105  Rahul  21.000000       1  Mumbai            AI   75.000000
# 5          106  Pooja  22.000000       0    Pune        Python   98.000000
# 6          107  Karan  20.000000       1  Nashik  Data Science   82.000000
# 7          108   Neha  21.000000       0    Pune            AI   91.000000
# 8          109  Akash  24.000000       1  Mumbai        Python   85.000000
# 9          110  Komal  23.000000       0    Pune  Data Science   96.000000
# 10         111  Vikas  21.666667       1    Pune        Python   90.000000
# ...

# %%
# One-Hot Encoding for City and Course

df_encoded = pd.get_dummies(
    df,
    columns=["City", "Course"],
    dtype=int
)

df_encoded
# Out:
#     Student_ID   Name        Age  Gender  Attendance      Marks  Purchased  \
# 0          101    Raj  21.000000       1   90.000000  85.000000          1
# 1          102   Amit  22.000000       1   80.000000  75.000000          0
# 2          103  Priya  20.000000       0   95.000000  92.000000          1
# 3          104  Sneha  23.000000       0   88.000000  81.000000          1
# 4          105  Rahul  21.000000       1   75.000000  65.000000          0
# 5          106  Pooja  22.000000       0   98.000000  96.000000          1
# 6          107  Karan  20.000000       1   82.000000  79.000000          0
# 7          108   Neha  21.000000       0   91.000000  89.000000          1
# 8          109  Akash  24.000000       1   85.000000  72.000000          0
# 9          110  Komal  23.000000       0   96.000000  94.000000          1
# 10         111  Vikas  21.666667       1   90.000000  83.166667          1
# ...

# %%
# Features
X = df[[
    "Age",
    "Attendance",
    "Marks",
    "Gender"
]]

# Target
y = df["Purchased"]

print("Features (X):")
print(X)

print("\nTarget (y):")
print(y)
# Out:
# Features (X):
#           Age  Attendance      Marks  Gender
# 0   21.000000   90.000000  85.000000       1
# 1   22.000000   80.000000  75.000000       1
# 2   20.000000   95.000000  92.000000       0
# 3   23.000000   88.000000  81.000000       0
# 4   21.000000   75.000000  65.000000       1
# 5   22.000000   98.000000  96.000000       0
# 6   20.000000   82.000000  79.000000       1
# 7   21.000000   91.000000  89.000000       0
# 8   24.000000   85.000000  72.000000       1
# 9   23.000000   96.000000  94.000000       0
# 10  21.666667   90.000000  83.166667       1
# 11  22.000000   88.333333  85.000000       0
# 12  21.000000   90.000000  85.000000       1
#
# Target (y):
# 0     1
# 1     0
# 2     1
# 3     1
# 4     0
# 5     1
# 6     0
# 7     1
# 8     0
# 9     1
# 10    1
# 11    0
# 12    1
# Name: Purchased, dtype: int64

# %%
# Save cleaned dataset

df.to_csv("cleaned_student_performance.csv", index=False)

print("cleaned_student_performance.csv saved successfully!")
# Out:
# cleaned_student_performance.csv saved successfully!
