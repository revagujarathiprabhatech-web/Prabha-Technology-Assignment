# %% [markdown]
# 04/06/2026
#
# Assignment : 3
#
# OOP : 1

# %% [markdown]
# CHALLENGE 1: STUDENT MANAGEMENT SYSTEM

# %%
class Student:

    # Class Variable
    school_name = "ABC College"

    # Constructor
    def __init__(self, name, age, course):
        self.name = name
        self.age = age
        self.course = course

    # Instance Method
    def display_student(self):
        print("Name :", self.name)
        print("Age :", self.age)
        print("Course :", self.course)
        print("School :", Student.school_name)
        print()

    # Class Method
    @classmethod
    def change_school_name(cls, new_name):
        cls.school_name = new_name


# Object Creation
student1 = Student("Reva", 19, "AI & ML")
student2 = Student("Amit", 20, "Computer")

print("Before Changing School Name")
student1.display_student()
student2.display_student()

# Change School Name
Student.change_school_name("Prabha Technology College")

print("After Changing School Name")
student1.display_student()
student2.display_student()
# Out:
# Before Changing School Name
# Name : Reva
# Age : 19
# Course : AI & ML
# School : ABC College
#
# Name : Amit
# Age : 20
# Course : Computer
# School : ABC College
#
# After Changing School Name
# Name : Reva
# Age : 19
# Course : AI & ML
# School : Prabha Technology College
#
# Name : Amit
# Age : 20
# Course : Computer
# School : Prabha Technology College

# %% [markdown]
# Challenge 2: Employee Counter

# %%
class Employee:

    # Class Variable
    employee_count = 0

    # Constructor
    def __init__(self, emp_id, emp_name, salary):
        self.emp_id = emp_id
        self.emp_name = emp_name
        self.salary = salary

        Employee.employee_count += 1

    # Instance Method
    def display_employee(self):
        print("Employee ID :", self.emp_id)
        print("Employee Name :", self.emp_name)
        print("Salary :", self.salary)
        print()

    # Class Method
    @classmethod
    def show_total_employees(cls):
        print("Total Employees :", cls.employee_count)


# Objects
emp1 = Employee(101, "Reva", 30000)
emp2 = Employee(102, "Amit", 35000)
emp3 = Employee(103, "Priya", 40000)

emp1.display_employee()
emp2.display_employee()
emp3.display_employee()

Employee.show_total_employees()
# Out:
# Employee ID : 101
# Employee Name : Reva
# Salary : 30000
#
# Employee ID : 102
# Employee Name : Amit
# Salary : 35000
#
# Employee ID : 103
# Employee Name : Priya
# Salary : 40000
#
# Total Employees : 3

# %% [markdown]
# Challenge 3: Bank Account System

# %%
class BankAccount:

    # Class Variable
    bank_name = "State Bank of India"

    # Constructor
    def __init__(self, account_number, holder_name, balance):
        self.account_number = account_number
        self.holder_name = holder_name
        self.balance = balance

    # Deposit Method
    def deposit(self, amount):
        self.balance += amount
        print(amount, "Deposited Successfully")

    # Withdraw Method
    def withdraw(self, amount):
        if amount <= self.balance:
            self.balance -= amount
            print(amount, "Withdrawn Successfully")
        else:
            print("Insufficient Balance")

    # Balance Method
    def check_balance(self):
        print("Current Balance :", self.balance)

    # Class Method
    @classmethod
    def change_bank_name(cls, new_name):
        cls.bank_name = new_name


# Objects
acc1 = BankAccount(1001, "Reva", 5000)
acc2 = BankAccount(1002, "Amit", 8000)

print("Bank Name :", BankAccount.bank_name)

acc1.deposit(2000)
acc1.withdraw(1000)
acc1.check_balance()

BankAccount.change_bank_name("HDFC Bank")

print("Updated Bank Name :", BankAccount.bank_name)
# Out:
# Bank Name : State Bank of India
# 2000 Deposited Successfully
# 1000 Withdrawn Successfully
# Current Balance : 6000
# Updated Bank Name : HDFC Bank

# %% [markdown]
# Challenge 4: Mobile Store Inventory

# %%
class Mobile:

    # Class Variable
    discount_percentage = 10

    # Constructor
    def __init__(self, brand, model, price):
        self.brand = brand
        self.model = model
        self.price = price

    # Display Method
    def display_mobile(self):
        print("Brand :", self.brand)
        print("Model :", self.model)
        print("Price :", self.price)

    # Discount Method
    def calculate_discount_price(self):
        discount = self.price * Mobile.discount_percentage / 100
        final_price = self.price - discount
        print("Discounted Price :", final_price)
        print()

    # Class Method
    @classmethod
    def change_discount(cls, new_discount):
        cls.discount_percentage = new_discount


# Objects
m1 = Mobile("Samsung", "S24", 70000)
m2 = Mobile("Apple", "iPhone 16", 90000)
m3 = Mobile("OnePlus", "13", 60000)

print("Before Discount Change")

m1.display_mobile()
m1.calculate_discount_price()

m2.display_mobile()
m2.calculate_discount_price()

m3.display_mobile()
m3.calculate_discount_price()

Mobile.change_discount(20)

print("After Discount Change")

m1.calculate_discount_price()
m2.calculate_discount_price()
m3.calculate_discount_price()
# Out:
# Before Discount Change
# Brand : Samsung
# Model : S24
# Price : 70000
# Discounted Price : 63000.0
#
# Brand : Apple
# Model : iPhone 16
# Price : 90000
# Discounted Price : 81000.0
#
# Brand : OnePlus
# Model : 13
# Price : 60000
# Discounted Price : 54000.0
#
# After Discount Change
# Discounted Price : 56000.0
#
# Discounted Price : 72000.0
#
# Discounted Price : 48000.0

# %% [markdown]
# Challenge 5: Library Book Management

# %%
class Book:

    # Class Variable
    library_name = "City Library"

    # Constructor
    def __init__(self, book_id, title, author):
        self.book_id = book_id
        self.title = title
        self.author = author

    # Instance Method
    def display_book_info(self):
        print("Book ID :", self.book_id)
        print("Title :", self.title)
        print("Author :", self.author)
        print("Library :", Book.library_name)
        print()

    # Class Method
    @classmethod
    def change_library_name(cls, new_name):
        cls.library_name = new_name


# Objects
book1 = Book(1, "Python Basics", "John")
book2 = Book(2, "AI Fundamentals", "David")
book3 = Book(3, "Data Science", "Emma")

print("Before Changing Library Name")

book1.display_book_info()
book2.display_book_info()
book3.display_book_info()

Book.change_library_name("Prabha Digital Library")

print("After Changing Library Name")

book1.display_book_info()
book2.display_book_info()
book3.display_book_info()
# Out:
# Before Changing Library Name
# Book ID : 1
# Title : Python Basics
# Author : John
# Library : City Library
#
# Book ID : 2
# Title : AI Fundamentals
# Author : David
# Library : City Library
#
# Book ID : 3
# Title : Data Science
# Author : Emma
# Library : City Library
#
# After Changing Library Name
# Book ID : 1
# Title : Python Basics
# Author : John
# Library : Prabha Digital Library
#
# Book ID : 2
# Title : AI Fundamentals
# Author : David
# Library : Prabha Digital Library
#
# Book ID : 3
# Title : Data Science
# Author : Emma
# Library : Prabha Digital Library
